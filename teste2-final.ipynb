# %% [markdown]
# # Teste 2
#
# ### Instruções
#
# * Leia atentamente cada questão
# * Preecha o nome e matrícula na célula abaixo
# * Você deve escolher 4 questões para resolver (cada uma vale 2.5 pts)
# * O teste é feito em duplas
# * Você pode consultar a documentação do Python em Python.org

# %% [markdown]
# ### Informações
#
# * Nome 1:
# * Matrícula 1:
# * Nome 2:
# * Matrícula 2:

# %% [markdown]
# ## Questão 1 - Maior Intervalo
#
# Você deve criar uma função que recebe um conjunto de inteiros e retorna um par com o maior intervalo contíguo. Por exemplo: `{1, 2, 3}` viraria o par `(1, 3)`. Caso o conjunto de números não seja sequencial, utilizamos o par que abrange o maior intervalo, dando preferência para os números maiores: `{1, 2, 3, 6, 7, 8} => (6, 8)`.
# Por fim, números isolados viram uma tupla com valores identicos: `{42} => (42, 42)`.

# %%
# id: q1
def maior_intervalo(data):
    return []

# %%
# Exemplo para você experimentar sua implementação :)
maior_intervalo({1, 2, 3, 4, 5, 7, 8, 12})
# Out:
# (1, 5)

# %%
# testes
assert maior_intervalo({1, 2, 3, 6, 7, 8, 4, 5}) == (1, 8), 'contiguo'
assert maior_intervalo({1, 2, 3, 4, 5, 7, 8, 12}) == (1, 5), 'separados'
assert maior_intervalo({1, 2, 3, 6, 7, 8}) == (6, 8), 'maior_numero'
print('Parabéns!')
# Out:
# Parabéns!

# %% [markdown]
# ## Questão 2 - Cifra de César
#
# O sistema de "criptografia" a seguir foi desenvolvido por Júlio César para trocar mensagens secretas entre os seus generais. Neste sistema, cada letra é trocada por uma letra n valores adiante. Por exemplo, se n = 1, a string "abc" seria codificada como "bce".
#
# Implemente uma função que realize a cifra de César trocando apenas o valor das letras, mas preservando a pontuação. Sua implementação pode assumir que a entrada não possui letras maiúsculas.

# %%
# id: q2
def cesar(data: str, n: int) -> str:
    return "abc"

# Dica: lembre-se das funções ord e chr!

# %%
# Exemplo para você experimentar sua implementação :)
cesar('paracatu', 2)
# Out:
# 'rctcecvw'

# %%
# testes
assert cesar('abc', 1) == 'bcd', 'simple'
assert cesar('xyz', 1) == 'yza', 'wrap'
assert cesar('hello world', 3) == 'khoor zruog', 'spaces'
assert cesar('hello, world!', 4) == 'lipps, asvph!', 'punctuation'
print('Parabéns!')
# Out:
# Parabéns!

# %% [markdown]
# ## Questão 3 - Todos diferentes
#
# Crie uma função que verifique se todos os elementos de uma lista são diferentes entre si.
#
# Uma lista vazia deve retornar `True`.

# %%
# id: q3
def todos_diferentes(lst: list) -> bool:
    return True or False

# %%
# Exemplo para você experimentar sua implementação :)
todos_diferentes([1, 1, 1])
# Out:
# False

# %%
# testes
assert todos_diferentes([1, 2, 3]) == True
assert todos_diferentes([1, 2, 1]) == False
assert todos_diferentes(['a', 'a', 'a']) == False
assert todos_diferentes([]) == True, 'vazio'
assert todos_diferentes([1]) == True, 'unico'
print('Parabéns!')
# Out:
# Parabéns!

# %% [markdown]
# ## Questão 4 - Repetições
#
# Seu programa deve receber uma lista de valores e idenficar quando houver repetições de dois ou mais valores consecutivos. O programa deve retornar o número máximo de repetições observado.

# %%
# id: q4
def repeticoes(lst: list) -> int:
    return 0

# %%
# Exemplo para você experimentar sua implementação :)
repeticoes([1, 1, 1, 2, 2, 3])
# Out:
# 3

# %%
# testes
assert repeticoes([1, 1, 1, 2, 2, 3]) == 3, 'comeco'
assert repeticoes([1, 2, 2, 3, 3, 3]) == 3, 'final'
assert repeticoes([1, 2, 2, 3]) == 2, 'meio'
assert repeticoes([1, 2, 3]) == 1, 'distintos'
print('Parabéns!')
# Out:
# Parabéns!

# %% [markdown]
# ## Questão 5 - Classe ponto
#
# A classe ponto representa um ponto num espaço 2D com as coordenadas x e y. Implemente os métodos "modulo()", "distancia()" e "__sub__()"  de acordo com as descrições fornecidas.

# %%
# id: q5
from math import sqrt


class Ponto:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def __repr__(self):
        return "Ponto(%r, %r)" % (self.x, self.y)
    
    def __eq__(self, other):
        return self.x == other.x and self.y == other.y
    
    def __add__(self, other):
        """Adição de vetores"""
        return Ponto(self.x + other.x, self.y + other.y)
    
    def __sub__(self, other):
        """Subtração de vetores"""
        return Ponto(0, 0)
    
    def modulo(self):
        """
        Retorna o módulo do vetor (i.e., sqrt(x**2 + y**2))
        """
        return 42
    
    def distancia(self, other):
        """
        Retorna a distância com relação a um segundo vetor other.
        """
        return 42

# %%
# Exemplo para você experimentar sua implementação :)
pt1 = Ponto(1, 2)
pt2 = Ponto(2, 1)
pt1 + pt2
# Out:
# Ponto(3, 3)

# %%
# testes
from math import sqrt
pt1 = Ponto(1, 2)
pt2 = Ponto(2, 1)
pt3 = Ponto(1, 1)

assert pt1 - pt2 == Ponto(-1, 1), 'subtracao'
assert pt1 - Ponto(0, 0) == pt1, 'subtracao'
assert pt1 - pt2 == Ponto(-1, 1), 'subtracao'
assert Ponto(3, 4).modulo() == 5, 'modulo'
assert pt1.distancia(pt2) == sqrt(2), 'distancia'
print('Parabens')
# Out:
# Parabens
